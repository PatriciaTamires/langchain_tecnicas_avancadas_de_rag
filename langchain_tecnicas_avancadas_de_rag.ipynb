# %% [markdown]
# Neste curso, vou aprender técnicas avançadas de RAG (Retrieval-Augmented Generation) utilizando LangChain
# , explorando estratégias para conectar modelos de IA a bases de conhecimento, melhorar a recuperação de informações e criar aplicações mais inteligentes, contextuais e eficientes.
